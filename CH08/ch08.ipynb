# %% [markdown]
# <div class="container">
#
# <nav id="TOC">
#
# *   [<span class="toc-section-number">1</span> Survol des librairies standards](#survol-des-librairies-standards)
#     *   [<span class="toc-section-number">1.1</span> Serveur web](#serveur-web)
#     *   [<span class="toc-section-number">1.2</span> `re`](#re)
#     *   [<span class="toc-section-number">1.3</span> `datetime`](#datetime)
#     *   [<span class="toc-section-number">1.4</span> `random`](#random)
#
# </nav>
#
# # <span class="header-section-number">1</span> Survol des librairies standards
#
# *   [https://docs.python.org/3/tutorial/stdlib.html](https://docs.python.org/3/tutorial/stdlib.html)
# *   [https://docs.python.org/3/tutorial/stdlib2.html](https://docs.python.org/3/tutorial/stdlib2.html)
#
# ## <span class="header-section-number">1.1</span> Serveur web
#
#     $ python3 -m http.server
#     Serving HTTP on 0.0.0.0 port 8000 ...
#
# <div class="panel panel-warning">
#
# <div class="panel-heading">
#
# ### Python 2
#
# </div>
#
# <div class="panel-body">
#
#     $ python -m SimpleHTTPServer
#     Serving HTTP on 0.0.0.0 port 8000 ...
#
# </div>
#
# </div>
#
# ## <span class="header-section-number">1.2</span> `re`
#
#     >>> import re
#     >>> m = re.match(r"(?P<first_name>\w+) (?P<last_name>\w+)", "Alex Tremblay")
#     >>> m.group('first_name')
#     'Alex'
#     >>> m.group('last_name')
#     'Tremblay'
#
# ## <span class="header-section-number">1.3</span> `datetime`
#
#     >>> d = datetime(2015, 6, 19, 14, 58)
#     >>> d
#     datetime.datetime(2015, 6, 19, 14, 58)
#     >>> d.isoformat()
#     '2015-06-19T14:58:00'
#     >>> d2 = datetime(2015, 6, 22, 16, 34)
#     >>> d2 - d
#     datetime.timedelta(3, 5760)
#
# ## <span class="header-section-number">1.4</span> `random`
#
#     >>> import random
#     >>> random.randrange(0, 101)
#     43
#     >>> random.randrange(0, 101)
#     56
#     >>> random.choice('abcdefghij')
#     'h'
#     >>> random.choice('abcdefghij')
#     'i'
#
# </div>
#
# <script type="text/javascript">$(function() { $(".solution").css("visibility", "hidden"); $(".btn-solution").click(function(e) { e.preventDefault(); $(this).parent().next(".solution").css('visibility', 'visible'); }); });</script>
